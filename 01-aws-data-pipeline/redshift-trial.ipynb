# %% [markdown]
# # Import Library

# %%
import boto3
import pandas as pd
import psycopg2 # for postgres
import json
import configparser # to read .config file

# %%
config = configparser.ConfigParser()
config.read_file(open('cluster.config'))

# %%
# Try to read key
config.get('AWS', 'KEY')
# Out:
# 'AKIAURWGSMJGKNIZB4UV'

# %%
# Define config variable from config file
KEY = config.get('AWS', 'KEY')
SECRET = config.get('AWS', 'SECRET')

DWH_CLUSTER_TYPE = config.get('DWH', 'DWH_CLUSTER_TYPE')
DWH_NUM_NODES = config.get('DWH', 'DWH_NUM_NODES')
DWH_NODE_TYPE = config.get('DWH', 'DWH_NODE_TYPE')

DWH_CLUSTER_IDENTIFIER = config.get('DWH', 'DWH_CLUSTER_IDENTIFIER')
DWH_DB = config.get('DWH', 'DWH_DB')
DWH_DB_USER = config.get('DWH', 'DWH_DB_USER')
DWH_DB_PASSWORD = config.get('DWH', 'DWH_DB_PASSWORD')
DWH_PORT = config.get('DWH', 'DWH_PORT')

DWH_IAM_ROLE_NAME = config.get('DWH', 'DWH_IAM_ROLE_NAME')

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)
# Out:
# ('awsuser', 'Passw0rd', 'myfirstdb')

# %%
pd.DataFrame({
    "Param": 
        ['DWH_CLUSTER_TYPE', 'DWH_NUM_NODES', 'DWH_NODE_TYPE', 'DWH_CLUSTER_IDENTIFIER', 'DWH_DB', 'DWH_DB_USER', 'DWH_DB_PASSWORD', 'DWH_PORT', 'DWH_IAM_ROLE_NAME'],
    "Value": 
        [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_DB_PASSWORD, DWH_PORT, DWH_IAM_ROLE_NAME]
})
# Out:
#                     Param                Value
# 0        DWH_CLUSTER_TYPE          single-node
# 1           DWH_NUM_NODES                    1
# 2           DWH_NODE_TYPE            dc2.large
# 3  DWH_CLUSTER_IDENTIFIER  try-naufal-redshift
# 4                  DWH_DB            myfirstdb
# 5             DWH_DB_USER              awsuser
# 6         DWH_DB_PASSWORD             Passw0rd
# 7                DWH_PORT                 5439
# 8       DWH_IAM_ROLE_NAME   redshift-s3-access

# %% [markdown]
# # Connect to  Required Amazon Services

# %%
# Connect to AWS EC2
ec2 = boto3.resource('ec2',
                     region_name='ap-southeast-3',
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                       )

# %%
# Connect to other resources
# Connect to AWS S3
s3 = boto3.resource('s3',
                     region_name='ap-southeast-3',
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                       )
# Connect to AWS IAM
iam = boto3.client('iam',
                     region_name='ap-southeast-3',
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                       )
# Connect to AWS Redshift
redshift = boto3.client('redshift',
                     region_name='ap-southeast-3',
                     aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET
                       )

# %%
# Try access bucket resources
bucket = s3.Bucket("naufal-redshift-trial-bucket")
log_data_files = [filename.key for filename in bucket.objects.filter(Prefix='')]
log_data_files
# Out:
# ['allevents_pipe.txt',
#  'allusers_pipe.txt',
#  'category_pipe.txt',
#  'date2008_pipe.txt',
#  'listings_pipe.txt',
#  'sales_tab.txt',
#  'venue_pipe.txt']

# %%
# Try access bucket resources but with filter
bucket = s3.Bucket("naufal-redshift-trial-bucket")
log_data_files = [filename.key for filename in bucket.objects.filter(Prefix='all')]
log_data_files
# Out:
# ['allevents_pipe.txt', 'allusers_pipe.txt']

# %% [markdown]
# # Attach iam permission to our cluster for security reason

# %%
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

# %%
# This is basically the url role of the user
roleArn
# Out:
# 'arn:aws:iam::312875311692:role/redshift-s3-access'

# %% [markdown]
# # Create Redshift Cluster

# %%
# For more info/other functions open Redshift sdk python docs
try:
    response = redshift.create_cluster(
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        
        # Identifier and credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        # Roles
        IamRoles=[roleArn]
    )
except Exception as e:
    print(e)

# %%
rs_info = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)
rs_info
# Out:
# {'Clusters': [{'ClusterIdentifier': 'try-naufal-redshift',
#    'NodeType': 'dc2.large',
#    'ClusterStatus': 'creating',
#    'ClusterAvailabilityStatus': 'Modifying',
#    'MasterUsername': 'awsuser',
#    'DBName': 'myfirstdb',
#    'AutomatedSnapshotRetentionPeriod': 1,
#    'ManualSnapshotRetentionPeriod': -1,
#    'ClusterSecurityGroups': [],
#    'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-01ed892c7b5358b3c',
#      'Status': 'active'}],
#    'ClusterParameterGroups': [{'ParameterGroupName': 'default.redshift-1.0',
#      'ParameterApplyStatus': 'in-sync'}],
#    'ClusterSubnetGroupName': 'default',
#    'VpcId': 'vpc-027a391276a2484a3',
#    'AvailabilityZone': 'ap-southeast-3b',
#    'PreferredMaintenanceWindow': 'sun:19:30-sun:20:00',
#    'PendingModifiedValues': {'MasterUserPassword': '****'},
#    'ClusterVersion': '1.0',
#    'AllowVersionUpgrade': True,
#    'NumberOfNodes': 1,
#    'PubliclyAccessible': True,
#    'Encrypted': False,
#    'ClusterPublicKey': 'ssh-rsa  Amazon-Redshift\n',
#    'ClusterNodes': [{'NodeRole': 'SHARED',
#      'PrivateIPAddress': '172.31.32.58',
#      'PublicIPAddress': '108.137.88.175'}],
#    'ClusterRevisionNumber': '43931',
#    'Tags': [],
#    'EnhancedVpcRouting': False,
#    'IamRoles': [{'IamRoleArn': 'arn:aws:iam::312875311692:role/redshift-s3-access',
#      'ApplyStatus': 'in-sync'}],
#    'MaintenanceTrackName': 'current',
#    'DeferredMaintenanceWindows': [],
#    'NextMaintenanceWindowStartTime': datetime.datetime(2022, 11, 27, 19, 30, tzinfo=tzutc()),
#    'AvailabilityZoneRelocationStatus': 'disabled',
#    'ClusterNamespaceArn': 'arn:aws:redshift:ap-southeast-3:312875311692:namespace:4574aa91-d03b-4f47-a0e1-745eaaf3f8cd',
#    'AquaConfiguration': {'AquaStatus': 'disabled',
#     'AquaConfigurationStatus': 'auto'}}],
#  'ResponseMetadata': {'RequestId': '3721c27b-6496-40e1-8769-19592b663cbe',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '3721c27b-6496-40e1-8769-19592b663cbe',
#    'content-type': 'text/xml',
#    'content-length': '3839',
#    'date': 'Sat, 26 Nov 2022 14:15:11 GMT'},
#   'RetryAttempts': 0}}

# %%
# Get only cluster info
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ['ClusterIdentifier', 'NodeType', 'ClusterStatus', 'MasterUsername', 'DBName', 'Endpoint', 'VpcId']
    x = [(k, v) for k, v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=['Key', 'Value'])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)
# Out:
# /tmp/ipykernel_5326/3461147287.py:3: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)
#                  Key  \
# 0  ClusterIdentifier
# 1  NodeType
# 2  ClusterStatus
# 3  MasterUsername
# 4  DBName
# 5  Endpoint
# 6  VpcId
#
#                                                                                                  Value
# 0  try-naufal-redshift
# 1  dc2.large
# 2  available
# 3  awsuser
# 4  myfirstdb
# 5  {'Address': 'try-naufal-redshift.crzycxx5xuqb.ap-southeast-3.redshift.amazonaws.com', 'Port': 5439}
# 6  vpc-027a391276a2484a3

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']
DB_NAME = myClusterProps['DBName']
DB_USER = myClusterProps['MasterUsername']

# %%
DB_NAME
# Out:
# 'myfirstdb'

# %% [markdown]
# ## Create VPC Security Group

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)
# Out:
# ec2.SecurityGroup(id='sg-01ed892c7b5358b3c')

# %% [markdown]
# # Connect Python with AWS Postgres DB

# %%
try:
    conn = psycopg2.connect(host=DWH_ENDPOINT, dbname=DB_NAME, user=DB_USER, password='Passw0rd', port=5439)
except Exception as e:
    print("Error: Could not make connection to the Postgres database")
    print(e)

# %%
conn.set_session(autocommit=True)

# %%
# Cursor is used to connect to AWS redshift
try:
    cur = conn.cursor()
except Exception as e:
    print("Error: Could not get cursor to Database")
    print(e)

# %% [markdown]
# # Create Table for DWH Based on Data's on Bucket alluser

# %%
try:
    cur.execute("""CREATE TABLE users(
    userid integer not null distkey sortkey,
    username char(8),
    firstname varchar(30),
    lastname varchar(30),
    city varchar(30),
    state char(2),
    email varchar(100),
    phone char(14),
    likesports boolean,
    liketheatre boolean,
    likeconcerts boolean,
    likejazz boolean,
    likeclassical boolean,
    likeopera boolean,
    likerock boolean,
    likevegas boolean,
    likebroadway boolean,
    likemusicals boolean);""")
except psycopg2.Error as e:
    print("Error: Issue creating table")
    print(e)

# %%
try:
    cur.execute("""CREATE TABLE venue(
    venueid smallint not null distkey sortkey,
    venuename varchar(100),
    venuecity varchar(30),
    venuestate char(2),
    venueseats integer);""")
except psycopg2.Error as e:
    print("Error: Issue creating table")
    print(e)

# %%
try:
    cur.execute("""CREATE TABLE category(
    catid smallint not null distkey sortkey,
    catgroup varchar(10),
    catname varchar(10),
    catdesc varchar(50));
    
    CREATE TABLE date(
    dateid smallint not null distkey sortkey,
    caldate date not null,
    day character(3) not null,
    week smallint not null,
    month character(5) not null,
    qtr character(5) not null,
    year smallint not null,
    holiday boolean default('N'));
    
    CREATE TABLE event(
    eventid integer not null distkey,
    venueid smallint not null,
    catid smallint not null,
    dateid smallint not null sortkey,
    eventname varchar(200),
    starttime timestamp);
    
    CREATE TABLE listing(
    listid integer not null distkey,
    sellerid integer not null,
    eventid integer not null,
    dateid smallint not null sortkey,
    numtickets smallint not null,
    priceperticket decimal(8,2),
    listtime timestamp);
    
    """)
except pyscopg2.Error as e:
    print("Error: Issue creating table")
    print(e)

# %% [markdown]
# # Copy data From AWS S3 into Redshift

# %%
# credentials are copied from aws iam redshift-s3-access arn
try:
    cur.execute("""
    copy users from 's3://naufal-redshift-trial-bucket/allusers_pipe.txt'
    credentials 'aws_iam_role=arn:aws:iam::312875311692:role/redshift-s3-access'
    delimiter '|'
    region 'ap-southeast-3'

    """)
except Exception as e:
    print("Error: Issue copying data")
    print(e)

# %%
# credentials are copied from aws iam redshift-s3-access arn
try:
    cur.execute("""
    SELECT * FROM users;
    """)
except Exception as e:
    print("Error: Connecting to database")
    print(e)

# %%
# Read rows of queried data
row = cur.fetchone()
while row:
    print(row)
    row = cur.fetchone()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# (44558, 'ICB17UXP', 'Mia', 'Suarez', 'Ketchikan', 'SK', 'fames@in.edu', '(311) 488-0150', None, None, False, False, False, None, None, None, None, None)
# (44559, 'DDJ59GOC', 'Roary', 'Mcmillan', 'Gastonia', 'WI', 'amet.orci.Ut@turpisNullaaliquet.ca', '(571) 605-0668', False, False, True, False, False, False, None, True, None, None)
# (44560, 'CXF69SUR', 'Hiram', 'Norman', 'Grambling', 'NL', 'arcu.Vestibulum@dictumsapienAenean.com', '(940) 256-0286', None, None, None, False, False, False, None, None, False, None)
# (44563, 'SVM65BHS', 'Vladimir', 'Whitehead', 'Port St. Lucie', 'AZ', 'quis.turpis@vulputatelacus.com', '(941) 214-7050', None, None, None, True, None, False, True, False, False, None)
# (44564, 'INK46XES', 'Joan', 'Copeland', 'Wahoo', 'WV', 'volutpat.Nulla.dignissim@tristiqueneque.edu', '(857) 904-8132', None, True, False, False, None, None, None, None, True, True)
# (44568, 'OGP29NZA', 'Ariel', 'Ward', 'Boston', 'PE', 'Nullam.velit@Nullamvelit.com', '(381) 485-1837', False, False, True, True, True, None, False, None, None, True)
# (44571, 'GLW08EKA', 'Ross', 'Rivera', 'Anaconda', 'KS', 'dolor.vitae@aliquetliberoInteger.org', '(286) 978-0085', None, None, True, None, False, None, False, False, None, True)
# (44573, 'VMI56XBB', 'Troy', 'Cooke', 'Concord', 'AK', 'mus.Donec@velitinaliquet.edu', '(228) 447-6567', True, None, None, None, True, None, False, None, None, None)
# (44575, 'CMU64BEU', 'Isabella', 'Miranda', 'Cincinnati', 'CA', 'neque.tellus@convallisin.ca', '(356) 346-7404', True, None, None, False, None, True, None, True, None, True)
# (44576, 'EGO46FDD', 'Constance', 'Mcneil', 'Two Rivers', 'MB', 'Quisque.ac.libero@mauriserateget.org', '(406) 127-5075', True, None, None, False, True, True, False, True, None, False)
# (44578, 'NTK32RBN', 'Donovan', 'Johnson', 'Inglewood', 'AZ', 'Integer.eu@lorem.com', '(721) 839-7781', None, False, True, None, None, None, None, True, None, True)
# (44581, 'GFF24UWY', 'Calvin', 'Brock', 'Topeka', 'MA', 'lorem.luctus.ut@fermentumfermentum.ca', '(644) 293-9867', None, None, None, False, True, None, True, None, True, True)
# (44584, 'BPY14XHY', 'Kenneth', 'Gray', 'Rancho Santa Margarita', 'SC', 'pede.nec.ante@ligula.com', '(942) 150-9038', None, False, None, None, None, False, None, False, None, None)
# (44585, 'XLT90UWC', 'Cain', 'Pollard', 'Irving', 'NL', 'ac.nulla@tellusnonmagna.edu', '(118) 153-8758', None, None, False, True, None, None, None, None, True, None)
# (44588, 'LLY12DQF', 'Emery', 'Whitfield', 'Mayagez', 'NL', 'auctor.ullamcorper@condimentumeget.edu', '(147) 192-1007', None, False, None, None, None, True, None, True, None, None)
# (44589, 'MOW54CRO', 'Callum', 'Hooper', 'West Haven', 'NC', 'metus.eu.erat@NulladignissimMaecenas.edu', '(110) 727-7072', None, True, None, True, False, None, False, None, None, False)
# (44592, 'AEP78APH', 'Neil', 'Randolph', 'Midwest City', 'WY', 'orci@Sed.org', '(370) 707-4589', None, True, False, None, True, None, None, None, False, False)
# (44594, 'RHB75OBD', 'Regina', 'Lambert', 'Council Bluffs', 'MN', 'ligula.eu.enim@mauris.com', '(976) 875-4362', None, False, False, True, None, None, None, None, None, None)
# (44596, 'DPS65HMI', 'Colette', 'Rivas', 'Eden Prairie', 'SK', 'eros.non.enim@adipiscingelit.com', '(770) 437-2115', None, True, None, None, None, True, None, False, False, None)
# (44600, 'XJO15MAL', 'Lisandra', 'Mosley', 'Dana Point', 'MB', 'egestas@idrisusquis.com', '(968) 275-2943', None, False, None, False, False, None, True, True, True, True)
# (44603, 'FBD26LAB', 'Rashad', 'Craig', 'Rialto', 'IA', 'Proin.dolor@Quisque.edu', '(463) 169-3687', None, True, None, None, True, False, True, None, False, None)
# (44604, 'TBY87WEJ', 'Naomi', 'Whitfield', 'Eden Prairie', 'BC', 'taciti.sociosqu.ad@nasceturridiculusmus.org', '(541) 919-0253', False, False, True, False, True, None, False, None, None, None)
# (44606, 'REZ61LBK', 'Daryl', 'Matthews', 'Saratoga Springs', 'SD', 'quis.arcu@auctorullamcorper.com', '(141) 311-1549', None, True, None, None, None, False, True, False, None, True)
# (44607, 'EZX50CQP', 'Karen', 'Madden', 'Bradbury', 'DE', 'Curabitur.ut@vulputatenisi.ca', '(756) 713-4476', True, False, None, True, False, True, True, False, None, True)
# (44613, 'IZF42RQR', 'Karly', 'Mccarthy', 'Culver City', 'NT', 'Fusce.diam.nunc@commodotinciduntnibh.ca', '(412) 947-3552', True, None, None, True, None, None, True, None, True, None)
# (44614, 'FIW17QMH', 'Dale', 'Robles', 'Seattle', 'YT', 'purus.in.molestie@penatibus.edu', '(464) 921-0588', None, None, None, True, None, True, None, None, None, True)
# (44618, 'QES50RCX', 'Tara', 'Casey', 'Hermitage', 'NS', 'Aliquam.vulputate.ullamcorper@Suspendissenon.com', '(881) 134-2098', None, True, None, False, False, None, False, None, None, True)
# (44619, 'JLW48GSW', 'Chloe', 'Lawson', 'Greenfield', 'NL', 'auctor@Loremipsumdolor.edu', '(423) 425-3879', None, False, True, False, True, True, None, None, True, None)
# (44620, 'CHL45YVK', 'Miriam', 'Rivera', 'Vallejo', 'CA', 'neque@maurisipsum.com', '(352) 362-2810', False, None, True, False, None, None, None, True, None, False)
# (44621, 'XBR26YMO', 'Brendan', 'Lara', 'Littleton', 'NY', 'mauris@ametultricies.org', '(797) 839-8004', None, False, False, None, False, False, False, None, None, None)
# (44625, 'HNO83HUQ', 'Joel', 'Sparks', 'Atwater', 'MI', 'malesuada@nibhlaciniaorci.ca', '(683) 989-3306', None, True, False, None, True, None, None, False, None, None)
# (44626, 'YAT98RHG', 'Otto', 'Tran', 'Orangeburg', 'SD', 'Mauris.magna.Duis@erategetipsum.edu', '(724) 753-2986', None, None, None, True, None, False, None, True, None, False)
# (44627, 'EBQ85YDO', 'Piper', 'Powers', 'Pueblo', 'IA', 'elit.erat.vitae@enim.org', '(482) 416-9174', True, True, None, None, None, None, None, False, None, False)
# (44628, 'CLF45YMT', 'Mikayla', 'Summers', 'New London', 'MS', 'pharetra@penatibus.org', '(179) 795-4901', False, None, True, None, None, None, None, False, True, None)
# (44629, 'OTB36QUQ', 'Michael', 'Wilkinson', 'Dalton', 'PE', 'vestibulum.massa.rutrum@necmalesuadaut.com', '(204) 240-6952', True, True, None, None, None, False, False, None, None, False)
# (44630, 'NBV65WJN', 'Ira', 'Maddox', 'Latrobe', 'MB', 'Donec.felis.orci@nislMaecenas.com', '(642) 833-2155', None, None, True, False, None, True, None, False, None, True)
# (44631, 'BCB84KDN', 'Virginia', 'Pratt', 'New Castle', 'TN', 'Proin.non.massa@liberonec.org', '(644) 364-1885', None, True, None, None, None, None, False, True, False, True)
# (44632, 'XKY10JHZ', 'Dai', 'Stevens', 'Kingston', 'SK', 'nec.imperdiet@congue.org', '(589) 671-4497', None, False, True, False, False, None, True, None, None, None)
# (44633, 'XDB59FAI', 'Ciaran', 'Robertson', 'Rensselaer', 'MN', 'sit@accumsansed.com', '(414) 819-1745', None, None, False, True, None, False, False, True, False, True)
# (44635, 'BOS77GDY', 'Gail', 'Rollins', 'Anaheim', 'NL', 'feugiat.tellus.lorem@lectusconvallis.edu', '(997) 268-4169', None, True, True, True, None, False, True, False, False, True)
# (44637, 'BAU96ZOR', 'Ray', 'Johns', 'Malden', 'NT', 'Vivamus.non@Phasellus.org', '(787) 148-6873', False, True, None, True, None, None, None, True, None, True)
# (44638, 'XUI92FPC', 'Thaddeus', 'Thomas', 'Woodward', 'ID', 'iaculis@maurisInteger.com', '(767) 586-3574', None, None, None, True, True, True, False, True, False, False)
# (44645, 'WXE15FEO', 'Walter', 'Miles', 'Charleston', 'NL', 'in.felis@dolordolor.org', '(774) 878-8643', None, None, None, None, None, None, None, None, None, True)
# (44646, 'SGJ40GIQ', 'Mikayla', 'Mooney', 'Riverton', 'SD', 'Donec.feugiat@luctus.org', '(456) 507-9909', None, False, None, False, None, None, True, False, None, True)
# (44647, 'NDH01BBD', 'Bell', 'Wilcox', 'Moline', 'AB', 'est.Nunc@quis.edu', '(422) 581-3915', None, False, None, None, False, None, None, True, None, True)
# (44653, 'HUV15UZG', 'Demetria', 'Zamora', 'Carolina', 'ON', 'lorem@consectetuercursus.ca', '(484) 513-4209', None, None, None, False, False, None, True, None, True, True)
# (44655, 'KJU35DQT', 'Geraldine', 'Rosales', 'Norman', 'NB', 'Morbi.vehicula@iaculis.org', '(229) 428-9355', None, False, None, True, None, True, None, True, None, True)
# (44657, 'NBY86RBV', 'Katell', 'Cooper', 'Passaic', 'AB', 'odio@luctusaliquet.ca', '(235) 852-4614', None, None, False, True, False, None, None, None, None, None)
# (44658, 'STQ52WAY', 'Acton', 'Lara', 'El Monte', 'NV', 'Donec.felis@ullamcorperviverraMaecenas.com', '(675) 121-1826', None, None, False, True, None, None, None, None, None, True)
# (44662, 'IGK63ORI', 'Otto', 'Curry', 'York', 'NB', 'laoreet.ipsum@ultrices.com', '(574) 726-2806', None, False, False, False, None, None, True, None, True, None)
# (44663, 'CDR74JAF', 'Heidi', 'Myers', 'Norman', 'AB', 'neque@sociis.com', '(709) 169-3779', None, None, True, None, False, False, None, True, None, None)
# (44668, 'KAQ18BWR', 'Charissa', 'Acevedo', 'Beacon', 'CO', 'amet.consectetuer@Loremipsumdolor.com', '(670) 734-5382', True, False, True, None, None, False, None, None, False, True)
# (44669, 'URZ59MBJ', 'Finn', 'Fry', 'Belleville', 'WI', 'tristique.pellentesque@atlacus.com', '(661) 909-0952', None, None, False, True, False, True, None, True, False, False)
# (44672, 'KIY19IZD', 'Lamar', 'Compton', 'La Mirada', 'RI', 'cursus.diam.at@pharetra.com', '(194) 404-8818', None, False, None, None, False, False, False, None, False, False)
# (44673, 'NPT95EUK', 'George', 'Mcgee', 'Texas City', 'TN', 'egestas.rhoncus.Proin@Maurisut.org', '(432) 815-9953', True, None, True, True, None, None, True, False, None, True)
# (44674, 'RCC42RKH', 'Daryl', 'Phelps', 'Sunbury', 'BC', 'dignissim.lacus.Aliquam@purusinmolestie.ca', '(160) 130-8821', None, False, None, True, None, None, None, None, None, None)
# (44675, 'ZZF02FWC', 'Isaac', 'Whitehead', 'Oakland', 'NS', 'Fusce.feugiat.Lorem@luctus.org', '(469) 589-6716', None, None, False, False, None, None, False, None, None, True)
# (44676, 'AQT54QEE', 'Rowan', 'Richmond', 'Detroit', 'MB', 'vulputate.lacus.Cras@natoquepenatibus.com', '(978) 149-3919', True, True, None, None, None, None, None, False, False, False)
# (44678, 'OUU39RSE', 'Dillon', 'Garza', 'Stillwater', 'DC', 'ad.litora@diamPellentesque.ca', '(952) 901-0012', True, True, None, None, False, None, None, True, False, None)
# (44679, 'AQW96BYT', 'Callum', 'Cooper', 'Philadelphia', 'SK', 'sodales.Mauris@pede.ca', '(911) 654-1502', False, None, None, False, True, None, False, False, None, False)
# (44682, 'STB74WLM', 'Octavia', 'Joyner', 'Sheridan', 'QC', 'lorem.fringilla.ornare@egestas.com', '(486) 720-4019', None, False, None, None, True, None, True, True, None, True)
# (44683, 'HPE98FKW', 'Hedda', 'Hall', 'Port Washington', 'PE', 'sit@acarcu.com', '(926) 392-9459', None, False, None, True, True, None, False, True, None, True)
# (44684, 'XEL21SER', 'Elliott', 'Bradford', 'West Valley City', 'IA', 'vehicula.et.rutrum@Sedid.edu', '(311) 671-2462', None, True, None, True, None, False, None, None, None, None)
# (44686, 'SUJ26ODQ', 'Colton', 'Valdez', 'Westminster', 'UT', 'vel.faucibus@necmaurisblandit.com', '(816) 982-9495', False, None, False, True, False, True, False, False, None, True)
# (44692, 'MBG47KYA', 'Indigo', 'Roberson', 'Norwalk', 'BC', 'facilisis.facilisis@Aliquamadipiscing.edu', '(303) 209-8645', None, False, None, False, False, None, None, True, False, None)
# (44693, 'JDB41AHV', 'Jane', 'Saunders', 'Oro Valley', 'SD', 'Phasellus.ornare.Fusce@at.org', '(197) 426-1112', None, None, None, False, None, None, False, True, None, True)
# (44694, 'AOQ38INB', 'Juliet', 'Rush', 'Hannibal', 'MI', 'ipsum@risusIn.ca', '(852) 953-6466', None, False, None, None, True, None, None, True, None, False)
# (44695, 'CLQ09ZTM', 'Lester', 'Horn', 'Mobile', 'BC', 'ut@duiinsodales.ca', '(472) 410-1743', False, None, None, False, False, False, None, None, None, None)
# (44696, 'NCC82EZB', 'Mason', 'Foley', 'Oxnard', 'OK', 'facilisi@lobortistellusjusto.com', '(371) 490-7408', False, True, None, None, None, None, None, False, None, None)
# (44697, 'STB07BUE', 'Bell', 'Middleton', 'Wynne', 'WI', 'blandit.enim.consequat@eu.com', '(397) 239-8732', None, False, None, None, False, None, None, None, False, True)
# (44700, 'MLB27FPK', 'Liberty', 'Strong', 'Fayetteville', 'CA', 'lobortis.ultrices.Vivamus@Nullamvitae.org', '(590) 672-1832', True, None, None, True, None, True, None, None, None, True)
# (44702, 'ABP69QUC', 'Adara', 'Pace', 'Danbury', 'NB', 'dictum.eu@magnis.org', '(554) 334-6676', None, None, None, None, None, False, None, True, True, None)
# (44705, 'UGM62KXI', 'Illiana', 'Bolton', 'Carson', 'VA', 'amet.ultricies.sem@hendreritnequeIn.com', '(219) 189-9358', None, None, None, None, True, None, None, False, False, False)
# (44708, 'SFZ29PVP', 'Zena', 'Giles', 'Kokomo', 'SK', 'nibh@fringillaeuismod.org', '(267) 111-4675', None, None, False, None, False, False, False, False, None, True)
# (44710, 'UQB92OTF', 'Hilda', 'Turner', 'Walnut', 'BC', 'nunc.In@blanditcongueIn.edu', '(948) 324-3643', False, None, None, True, False, True, None, True, None, False)
# (44714, 'FTS66IZA', 'Chastity', 'Graves', 'Laguna Hills', 'DE', 'magna@loremfringilla.ca', '(419) 218-6552', False, True, None, False, None, None, True, None, None, True)
# (44715, 'DXW30SZO', 'Elijah', 'Copeland', 'Haverhill', 'NY', 'Donec.tincidunt@sodales.ca', '(452) 147-2590', None, None, False, None, True, False, False, None, None, True)
# (44721, 'EOP97BWA', 'Maile', 'Webb', 'Santa Clarita', 'NT', 'a.auctor.non@Duis.org', '(798) 911-7321', None, True, None, False, None, None, False, None, True, None)
# (44722, 'NEZ43EFR', 'Hedy', 'Grant', 'Rawlins', 'NS', 'ipsum@eratEtiamvestibulum.edu', '(141) 323-7095', None, None, True, None, None, None, None, False, False, None)
# (44725, 'VKW65PLO', 'Selma', 'Randolph', 'Brunswick', 'RI', 'eget@tinciduntvehicula.edu', '(525) 350-9699', None, True, None, None, False, False, None, False, None, None)
# (44726, 'JOY61APV', 'Velma', 'Lindsey', 'Chino Hills', 'IA', 'Lorem.ipsum@Quisque.org', '(293) 208-6215', True, None, False, None, None, False, None, None, False, True)
# (44727, 'PMX74RKT', 'Russell', 'Wiley', 'Hagerstown', 'VA', 'enim.gravida.sit@lectuspedeultrices.org', '(974) 394-4629', None, True, None, None, False, False, True, False, None, True)
# (44728, 'PKE83QJA', 'Vera', 'Foster', 'Darlington', 'TX', 'est.mollis@vitae.ca', '(993) 259-9806', False, True, None, False, None, False, None, None, False, None)
# (44731, 'LJH61BYC', 'Leslie', 'Warren', 'Elmira', 'SK', 'laoreet.ipsum.Curabitur@malesuadaaugue.ca', '(804) 912-3214', None, False, False, None, None, None, True, False, False, True)
# (44732, 'ZWD90JIH', 'Kibo', 'Rosa', 'Rutland', 'OK', 'lobortis.Class@feliseget.org', '(761) 130-8789', True, None, False, False, True, None, True, None, None, None)
# (44733, 'LBW53XID', 'Odessa', 'Dominguez', 'Palm Springs', 'MB', 'orci.Donec.nibh@fringillapurus.com', '(333) 830-9806', None, None, True, True, False, None, None, False, None, None)
# (44738, 'SCA74DOS', 'Claire', 'Valenzuela', 'West Allis', 'WI', 'tellus.sem@ipsum.com', '(869) 599-3467', None, None, None, True, None, False, None, True, None, True)
# (44740, 'OGK15UQT', 'Mark', 'Cruz', 'Slidell', 'NT', 'erat.vitae.risus@Fuscefermentum.org', '(790) 854-1604', True, None, None, True, None, False, True, True, False, None)
# (44741, 'DCE96QCH', 'Odysseus', 'Kerr', 'Danbury', 'NS', 'turpis.nec.mauris@dui.com', '(622) 929-7141', None, None, None, None, None, True, False, False, False, False)
# (44742, 'RGH54GHR', 'Paloma', 'Hunt', 'Appleton', 'NL', 'elit@fringillaornare.com', '(980) 553-4815', False, None, True, False, None, False, False, False, None, True)
# (44743, 'FPQ61YEZ', 'Angelica', 'Patton', 'Tacoma', 'NB', 'odio.Etiam.ligula@purusac.ca', '(995) 388-0913', True, None, None, None, None, None, False, None, True, True)
# (44746, 'MLI67GKL', 'Kylee', 'Reed', 'Bremerton', 'HI', 'orci.quis.lectus@ridiculus.ca', '(772) 655-1163', None, None, True, True, None, False, None, True, None, False)
# (44747, 'UKR39EOD', 'Shoshana', 'Wilkins', 'Port Huron', 'TN', 'nec@sedconsequat.edu', '(688) 807-7027', True, None, False, True, None, None, None, False, False, None)
# (44748, 'TAT61NIE', 'Orla', 'Britt', 'Utica', 'NL', 'hendrerit.Donec.porttitor@semper.edu', '(455) 378-9150', None, None, None, True, False, True, True, False, None, False)
# (44750, 'SVF32FRC', 'Dustin', 'Nieves', 'Narragansett', 'NU', 'rhoncus.Proin@est.edu', '(883) 318-5912', None, False, None, None, None, True, None, None, False, True)
# (44751, 'BVB39XXX', 'Amela', 'Butler', 'Ada', 'AK', 'est@mus.com', '(410) 334-4105', None, True, None, True, True, None, False, True, True, None)
# (44755, 'ANU03KMN', 'Mara', 'Mckinney', 'Elkhart', 'HI', 'sit.amet.metus@perinceptos.ca', '(763) 494-7893', None, True, None, None, True, None, True, True, False, None)
# (44758, 'MEK02RBD', 'Mara', 'Everett', 'Temecula', 'WY', 'elementum.dui@consequat.ca', '(779) 490-3153', None, None, True, True, True, None, None, None, False, None)
# (44759, 'WVL27MQZ', 'Amir', 'William', 'Augusta', 'YT', 'sociis@ultricesposuerecubilia.org', '(487) 908-0640', None, False, None, True, None, False, True, False, None, None)
# (44763, 'AZF08LWP', 'Odette', 'Fletcher', 'Northampton', 'NV', 'ultricies@imperdieterat.ca', '(297) 706-0553', False, False, None, None, None, True, False, True, False, None)
# (44765, 'ZQY95WRZ', 'Plato', 'Howard', 'St. Marys', 'NT', 'vel.est@tinciduntaliquam.com', '(226) 585-1149', None, None, True, None, False, None, True, False, False, None)
# (44767, 'ETS89VAM', 'Sylvia', 'Greene', 'Glendora', 'CO', 'eu.neque.pellentesque@insodales.com', '(970) 236-5924', None, False, True, True, None, True, None, None, True, False)
# (44769, 'POH80TIJ', 'Tanek', 'Pickett', 'Indianapolis', 'VT', 'non@Integertincidunt.org', '(591) 522-1041', None, True, True, None, None, True, None, False, False, None)
# (44771, 'DPS07OOJ', 'Uma', 'Brennan', 'Jenks', 'GA', 'porttitor@amet.ca', '(156) 166-0449', False, True, None, None, False, False, None, None, None, None)
# (44773, 'KDL80CJO', 'Aspen', 'Barry', 'East Lansing', 'TX', 'lorem@sed.ca', '(782) 987-3254', None, None, False, False, True, None, None, False, True, True)
# (44774, 'ORC45VVU', 'Harriet', 'Foreman', 'Redlands', 'DC', 'amet.luctus@utquamvel.edu', '(611) 531-0508', None, None, True, True, None, False, False, False, None, False)
# (44775, 'LUG90MZQ', 'Karleigh', 'Savage', 'Zanesville', 'NT', 'sed.facilisis@anteipsum.ca', '(947) 139-0698', None, None, None, False, False, None, False, False, None, None)
# (44778, 'MKT32KHM', 'Luke', 'Knapp', 'Bradbury', 'NS', 'nunc.sit@pede.ca', '(857) 693-6604', None, True, None, True, True, None, None, None, False, None)
# (44781, 'COQ12JEM', 'Orlando', 'Sutton', 'Downey', 'NL', 'ipsum.nunc.id@leoCras.edu', '(740) 685-1655', None, None, True, None, None, False, None, True, None, None)
# (44783, 'GAR12TOL', 'Cadman', 'Barron', 'Terre Haute', 'SK', 'risus@purusMaecenaslibero.org', '(972) 107-6594', None, None, True, None, None, None, None, None, None, True)
# (44785, 'NZL23QDC', 'Shannon', 'Best', 'Lexington', 'PE', 'eu.erat@sedconsequat.org', '(763) 308-5684', True, False, None, False, None, None, False, True, None, False)
# (44787, 'BQQ04IYE', 'Jerome', 'Dawson', 'New Albany', 'QC', 'Duis.gravida@Sedcongue.org', '(814) 754-0506', True, False, True, None, None, True, False, None, True, None)
# (44790, 'JCL84IDZ', 'Velma', 'Talley', 'Rochester', 'VT', 'Curae;.Donec@Sed.edu', '(545) 169-9070', None, None, None, None, False, None, False, None, False, None)
# (44791, 'TUN74MRM', 'Dakota', 'Oliver', 'LaGrange', 'AK', 'nisl.arcu.iaculis@est.org', '(639) 990-1194', False, None, True, True, None, None, False, None, False, False)
# (44793, 'CGC80CXR', 'Pearl', 'Delacruz', 'Bristol', 'NV', 'porta.elit.a@Proinvel.edu', '(830) 836-9188', True, False, True, True, None, True, None, None, None, True)
# (44794, 'WWP62FOJ', 'Aretha', 'Hughes', 'Stamford', 'MA', 'In.faucibus.Morbi@estNunc.edu', '(979) 574-9789', None, None, None, None, False, None, True, None, None, False)
# (44795, 'QRD14PBF', 'Isaiah', 'Alford', 'Manassas Park', 'SC', 'posuere.at.velit@ac.com', '(917) 686-8375', None, None, None, False, False, None, False, True, None, True)
# (44796, 'ZVK56AKB', 'Raven', 'Wheeler', 'Hawaiian Gardens', 'PE', 'magna.sed.dui@accumsanconvallisante.ca', '(552) 654-5296', True, False, None, None, None, True, True, None, None, True)
# (44797, 'NKG19TTD', 'Merritt', 'Gilliam', 'Appleton', 'WA', 'aliquam.arcu@Mauris.org', '(621) 488-6296', None, None, None, False, True, None, False, None, None, False)
# (44798, 'AAF48BBC', 'Alexis', 'Obrien', 'Cape Coral', 'TN', 'sem@purusgravidasagittis.edu', '(576) 179-3037', True, True, None, False, True, True, True, None, False, None)
# (44799, 'VVT85RFO', 'Abraham', 'Yang', 'Evanston', 'NT', 'risus@consectetuereuismod.com', '(342) 110-4098', None, True, False, True, None, False, True, None, True, True)
# (44800, 'EBE21FSE', 'Charity', 'Leach', 'Durant', 'NB', 'orci@Aeneaneget.com', '(612) 907-2031', False, False, True, False, None, False, None, None, False, False)
# (44802, 'RPJ54HVM', 'Taylor', 'Daugherty', 'Irving', 'PE', 'vel.turpis.Aliquam@ligulaAenean.ca', '(928) 200-8120', None, False, None, None, False, None, True, None, False, None)
# (44804, 'IQK28ROX', 'Sarah', 'Sloan', 'Bowling Green', 'CT', 'sed.libero@nibhDonecest.ca', '(775) 319-2356', None, None, None, None, None, False, None, True, None, False)
# (44805, 'NPU87TBC', 'Dillon', 'Norton', 'Rock Springs', 'NU', 'lacus@ante.org', '(291) 308-1718', None, None, None, False, None, True, True, False, None, True)
# (44806, 'CUB38XMP', 'Alden', 'Gonzales', 'Cohoes', 'NT', 'enim.nisl@Fusce.com', '(462) 248-0639', None, None, None, None, False, None, True, None, True, False)
# (44807, 'YKP19MDN', 'Rhoda', 'Boyer', 'Agat', 'AB', 'ante.Nunc@Praesentinterdum.com', '(287) 147-3779', None, True, None, None, None, None, False, False, True, False)
# (44808, 'DTD12WNX', 'Laurel', 'Hines', 'Glendale', 'NU', 'justo@molestiepharetranibh.com', '(316) 510-0490', None, None, None, None, None, None, True, True, True, None)
# (44809, 'WGY33ZMV', 'Wallace', 'Lloyd', 'Clarksburg', 'NL', 'aliquet.magna.a@viverraMaecenas.ca', '(731) 397-9766', True, None, True, False, None, True, None, False, False, None)
# (44811, 'AJZ92IRG', 'Heidi', 'Odonnell', 'Pittsburgh', 'OR', 'dolor.vitae@magna.ca', '(614) 776-2419', None, False, True, True, None, None, None, True, None, True)
# (44812, 'JWK06AIE', 'Cecilia', 'Cummings', 'Everett', 'DE', 'senectus@eratneque.org', '(609) 429-0208', False, False, None, None, True, True, None, False, False, None)
# (44813, 'WDN24LIQ', 'Jaime', 'Butler', 'Manitowoc', 'NT', 'Cum.sociis.natoque@doloregestasrhoncus.edu', '(387) 206-8360', None, True, None, None, True, False, None, None, None, None)
# (44815, 'TEQ97HSI', 'Gay', 'Norton', 'Alameda', 'DC', 'lorem.auctor@necdiam.edu', '(555) 475-6523', None, None, None, True, None, None, None, None, True, None)
# (44816, 'ASR44FBZ', 'Isaac', 'Harris', 'City of Industry', 'MN', 'Proin@anteipsum.com', '(157) 574-6532', None, None, True, None, True, None, None, True, None, False)
# (44817, 'IKF81QOT', 'Adria', 'Robbins', 'La Palma', 'AZ', 'tincidunt.Donec.vitae@mauriselitdictum.com', '(706) 742-3035', True, None, True, False, None, None, None, True, False, None)
# (44819, 'LQA14TLD', 'Erasmus', 'Doyle', 'West Hartford', 'FL', 'id.erat.Etiam@Nullafacilisis.edu', '(838) 803-8113', None, True, False, None, None, False, True, None, True, True)
# (44821, 'RLH14QXC', 'Seth', 'Marsh', 'Hampton', 'WV', 'Nullam.scelerisque.neque@aneque.edu', '(940) 764-6242', None, False, None, None, None, True, False, None, None, False)
# (44822, 'WLM51ZFI', 'Harlan', 'Kirk', 'Revere', 'MN', 'blandit@dictumcursusNunc.com', '(210) 904-1980', None, None, None, True, False, None, True, None, None, True)
# (44826, 'FTF59DHS', 'Hope', 'Allison', 'West Valley City', 'IN', 'magna.Ut.tincidunt@ametmassa.ca', '(169) 605-4527', None, None, False, True, True, True, None, True, False, None)
# (44827, 'LWN09AMM', 'Constance', 'Duran', 'Springfield', 'NT', 'In.at.pede@Maecenas.org', '(935) 736-4347', False, None, None, None, True, True, None, True, None, None)
# (44828, 'SQF30XVJ', 'Fredericka', 'Mcconnell', 'Urbana', 'NB', 'rutrum.Fusce.dolor@idantedictum.org', '(586) 399-9897', None, True, True, True, None, None, None, False, None, None)
# (44829, 'TCM00KYY', 'Francesca', 'Olson', 'Citrus Heights', 'YT', 'quis.pede.Suspendisse@nullaanteiaculis.org', '(268) 498-9091', None, None, False, True, None, True, True, True, True, None)
# (44830, 'VVZ28VCW', 'Nyssa', 'Davis', 'Christiansted', 'CO', 'imperdiet.nec@eu.ca', '(513) 109-7653', False, True, None, False, None, True, True, None, False, None)
# (44832, 'TFP13YRR', 'Ashton', 'Hayden', 'Las Vegas', 'TN', 'tincidunt@Morbiquisurna.ca', '(345) 823-3752', None, False, None, None, False, None, False, None, None, False)
# (44833, 'JKQ26ZOL', 'Kaden', 'Saunders', 'West Memphis', 'TN', 'arcu@feugiatnecdiam.ca', '(540) 741-8639', None, None, True, None, None, False, True, True, True, None)
# (44835, 'UJX01OER', 'Ariel', 'Tucker', 'Fairfax', 'NB', 'at@dictumProineget.edu', '(533) 618-1697', False, None, False, True, None, False, False, False, False, None)
# (44836, 'ZLJ66FUH', 'Clarke', 'Leblanc', 'Chula Vista', 'NB', 'Etiam@Morbiquisurna.com', '(820) 214-9134', None, True, None, True, False, None, None, None, None, None)
# (44837, 'WQK07VZX', 'Daniel', 'Hicks', 'College Station', 'TX', 'ac.sem@bibendum.ca', '(862) 606-8768', None, False, False, None, None, None, None, None, True, True)
# (44839, 'IDH06VFU', 'Evangeline', 'Cain', 'The Dalles', 'ND', 'lorem.vehicula.et@velitQuisquevarius.com', '(735) 153-5387', None, None, None, False, False, None, False, None, False, False)
# (44840, 'YZQ04AOU', 'Stella', 'Garrett', 'Thiensville', 'NS', 'In.ornare@dictum.ca', '(821) 482-6188', True, True, False, False, False, True, False, None, False, False)
# (44842, 'LJY76JDK', 'Grace', 'Lindsey', 'Plattsburgh', 'SD', 'velit.Quisque@Maurisutquam.ca', '(560) 767-2872', True, None, None, True, None, None, True, False, None, False)
# (44844, 'WDP18VKV', 'Holmes', 'Hawkins', 'Hartford', 'MB', 'non@fermentumfermentumarcu.org', '(992) 879-5901', None, None, None, True, False, None, None, None, None, True)
# (44847, 'DFU47XCF', 'Ashely', 'Pate', 'Bayamon', 'PE', 'congue@Pellentesquehabitantmorbi.edu', '(743) 815-9251', None, None, False, None, None, False, None, False, None, None)
# (44848, 'ZQU88IUC', 'Shaine', 'Tran', 'Enid', 'CT', 'fames.ac.turpis@nullaIntegervulputate.org', '(211) 616-2494', None, None, None, None, None, None, False, None, None, None)
# (44849, 'EKX75PZB', 'Kalia', 'Joyce', 'Raleigh', 'SK', 'nascetur.ridiculus.mus@Donec.com', '(475) 847-0780', None, None, True, True, None, None, None, False, True, False)
# (44850, 'JNU29NGT', 'Gail', 'Dunlap', 'San Rafael', 'SK', 'diam@Morbi.com', '(277) 910-7487', None, True, None, None, True, False, False, True, True, None)
# (44851, 'YWP89RQL', 'Joshua', 'Golden', 'Ponce', 'NS', 'lobortis@consectetuer.edu', '(720) 182-6583', False, False, None, None, True, None, None, None, None, False)
# (44852, 'EHO20VWR', 'Myra', 'Cohen', 'Grand Junction', 'MI', 'Ut.tincidunt.orci@elitelit.com', '(335) 930-1725', True, False, None, None, True, None, None, False, None, False)
# (44853, 'QEZ65AVH', 'Ella', 'Harvey', 'Ypsilanti', 'DE', 'ipsum.leo@Cum.edu', '(830) 955-8662', None, False, False, None, False, False, None, None, None, None)
# (44855, 'GHI43AEG', 'Olga', 'Hooper', 'Indianapolis', 'NT', 'arcu@eget.edu', '(224) 411-6361', False, None, True, False, False, False, True, None, True, True)
# (44857, 'PKS95JWS', 'Liberty', 'Howard', 'Laredo', 'NT', 'ac@utlacusNulla.com', '(143) 659-8393', None, False, False, True, False, None, False, True, False, None)
# (44860, 'VQM28KSS', 'Nerea', 'Flynn', 'Houston', 'NT', 'id.erat.Etiam@sitametmetus.org', '(958) 970-0938', True, None, True, True, False, False, True, True, False, False)
# (44861, 'IGG29IHZ', 'Mariam', 'Bush', 'Laguna Woods', 'SD', 'nulla.In.tincidunt@porttitortellus.com', '(302) 480-9793', None, True, True, False, True, None, None, True, False, None)
# (44864, 'MIG83EGO', 'Conan', 'Mckenzie', 'Gilbert', 'NS', 'augue.Sed@Namnullamagna.edu', '(992) 353-3620', False, None, None, None, None, None, True, False, None, None)
# (44865, 'NHM78VCN', 'Aretha', 'Burks', 'Fremont', 'QC', 'sit.amet.consectetuer@eueratsemper.org', '(948) 337-0896', None, None, False, None, True, None, None, False, False, None)
# (44866, 'KRI60CTW', 'Adara', 'Hahn', 'Apple Valley', 'MB', 'odio.vel.est@idrisusquis.com', '(676) 703-3217', None, None, False, True, None, None, None, True, False, None)
# (44869, 'KIA51JLX', 'Donna', 'Bass', 'Louisville', 'NB', 'lacinia.vitae.sodales@Crasloremlorem.edu', '(220) 132-2061', None, False, None, None, True, False, False, None, False, None)
# (44873, 'YQW24YZU', 'Grant', 'Burch', 'Missoula', 'TN', 'condimentum.eget.volutpat@Namconsequat.edu', '(790) 529-8671', None, None, None, None, None, None, None, False, False, None)
# (44877, 'YFZ76QRO', 'Kathleen', 'Mccoy', 'Rock Island', 'NB', 'tristique@a.ca', '(838) 566-3165', False, None, None, None, None, None, None, None, None, True)
# (44879, 'SHL89UHB', 'Cedric', 'Cleveland', 'Alexandria', 'NS', 'at.auctor.ullamcorper@bibendum.com', '(221) 171-9755', None, True, None, False, True, True, None, True, None, None)
# (44881, 'AIW52YCF', 'Dale', 'Potter', 'Melrose', 'OH', 'massa.rutrum.magna@molestieorcitincidunt.org', '(342) 239-4806', None, True, None, None, None, None, True, None, False, False)
# (44882, 'JFT55SAM', 'Paloma', 'Oneill', 'Visalia', 'ME', 'ante.blandit.viverra@lectusconvallisest.edu', '(911) 809-0572', None, True, None, False, False, True, False, None, False, None)
# (44888, 'VLN88ESY', 'Felix', 'Mosley', 'Greensboro', 'NS', 'Sed@purusDuiselementum.ca', '(398) 148-6915', False, None, None, True, False, False, None, True, None, None)
# (44889, 'UFC86YMO', 'Amal', 'Wolf', 'Brownsville', 'AB', 'nec.mauris@nibhAliquamornare.com', '(730) 985-4579', True, None, True, False, None, None, None, None, False, False)
# (44890, 'EHM00BMR', 'Samson', 'Haynes', 'Lock Haven', 'CO', 'ridiculus.mus.Donec@amet.org', '(597) 891-2607', True, True, True, False, True, False, True, False, True, None)
# (44892, 'CLI36TFJ', 'Sopoline', 'Bean', 'Lake Forest', 'IA', 'metus@vitaemauris.org', '(168) 391-8949', False, None, None, None, None, True, True, True, False, False)
# (44897, 'CIO01TPM', 'Adam', 'Wheeler', 'Bradford', 'YT', 'Cras@lectus.ca', '(525) 827-0683', None, False, None, None, None, None, None, False, None, None)
# (44898, 'IOM18GGM', 'Calvin', 'Mcpherson', 'South Bend', 'AK', 'ut.eros@metus.org', '(677) 992-8336', False, None, None, False, None, None, None, True, False, None)
# (44900, 'EQW84TIW', 'Fatima', 'Ward', 'Las Cruces', 'MB', 'arcu@lectusquismassa.ca', '(636) 415-1589', False, None, True, False, True, None, None, None, True, True)
# (44901, 'JZI71WWT', 'Natalie', 'Russell', 'Flint', 'NU', 'feugiat.tellus@scelerisque.edu', '(762) 777-8966', False, True, True, True, None, None, False, None, None, False)
# (44902, 'CRO84ISI', 'Whilemina', 'Griffin', 'Slidell', 'NB', 'Mauris.blandit.enim@Curabitur.ca', '(462) 245-3576', None, None, True, False, True, True, None, None, None, False)
# (44904, 'OHL94NLT', 'Sara', 'Blankenship', 'Macon', 'MB', 'ut.sem.Nulla@Seddiamlorem.edu', '(756) 136-4475', False, None, None, None, None, True, None, None, False, None)
# (44906, 'FXQ28MPU', 'Gisela', 'Buckley', 'Aberdeen', 'NB', 'ac.fermentum.vel@duiFusce.ca', '(407) 837-7577', True, True, None, None, None, False, None, None, None, None)
# (44908, 'DFH14UJS', 'Nash', 'Ford', 'Ann Arbor', 'QC', 'ut.sem.Nulla@vel.ca', '(188) 682-3716', None, None, False, None, None, False, True, True, None, None)
# (44910, 'ZJF58EVD', 'Christine', 'Tillman', 'Sault Ste. Marie', 'WA', 'enim.Etiam@PhasellusornareFusce.edu', '(790) 414-7303', None, None, False, True, None, False, True, None, None, False)
# (44913, 'TNN29ZAN', 'Ruby', 'Franks', 'Bowling Green', 'QC', 'sapien.gravida@ultricesaauctor.edu', '(460) 229-4392', None, True, None, False, None, False, None, True, None, None)
# (44915, 'HTB72JUQ', 'Acton', 'Hickman', 'Bismarck', 'BC', 'Integer.vulputate.risus@nullaat.com', '(896) 148-8632', None, None, None, False, True, None, True, None, None, None)
# (44917, 'MCS29FKR', 'August', 'Fitzgerald', 'Hammond', 'SD', 'adipiscing.lacus@sem.org', '(231) 708-6003', None, None, None, True, True, False, None, None, False, False)
# (44919, 'NXG83LOV', 'Finn', 'Manning', 'Tampa', 'CA', 'ipsum.dolor@tellus.com', '(419) 197-5360', None, None, None, None, None, False, True, None, None, True)
# (44922, 'IYL99CYW', 'Farrah', 'Dixon', 'Wilkes-Barre', 'ID', 'convallis.ante.lectus@Morbi.org', '(366) 391-4049', None, True, None, False, False, None, True, None, None, None)
# (44925, 'AEQ78OCM', 'Zephr', 'Estes', 'West Jordan', 'SK', 'arcu.Curabitur@Maurisutquam.com', '(770) 993-8944', None, None, None, None, False, True, True, None, True, False)
# (44929, 'RVQ72VNI', 'Lavinia', 'Crosby', 'Lincoln', 'MN', 'Nullam.velit.dui@interdumfeugiatSed.com', '(373) 957-2637', False, False, None, None, None, True, None, True, False, False)
# (44930, 'ULM79GAQ', 'Lila', 'Pugh', 'La Canada Flintridge', 'NB', 'molestie.Sed@Aliquam.ca', '(467) 260-8573', None, False, True, True, None, True, None, False, None, True)
# (44931, 'IPR42TIU', 'Ira', 'Noel', 'Artesia', 'SC', 'Donec.tempus@necorci.org', '(722) 560-3803', None, None, None, None, None, None, None, None, True, False)
# (44932, 'HZL76LEM', 'Kai', 'Lester', 'Dover', 'HI', 'neque@erat.ca', '(640) 950-1266', True, False, True, True, None, None, True, True, None, True)
# (44935, 'TLP20POQ', 'Beau', 'Greer', 'West Haven', 'NB', 'nostra.per.inceptos@ipsumSuspendisse.com', '(517) 371-1114', False, None, None, None, None, None, True, None, True, None)
# (44936, 'FNB42FQL', 'Helen', 'Blanchard', 'Hopkinsville', 'IA', 'erat@sed.ca', '(471) 548-5872', None, False, False, None, None, True, None, False, True, False)
# (44937, 'JOQ89LJW', 'Camilla', 'Medina', 'Charlotte', 'AK', 'adipiscing@blanditatnisi.org', '(511) 430-0679', None, True, None, None, False, None, False, True, None, None)
# (44938, 'JNW78YTO', 'Murphy', 'Parrish', 'West Hartford', 'AK', 'malesuada.ut.sem@semelitpharetra.org', '(638) 690-5724', None, True, True, False, None, False, None, False, None, None)
# (44940, 'QHC22SUI', 'Kiona', 'Blair', 'La Mirada', 'NB', 'at.pretium.aliquet@Mauris.edu', '(464) 948-5265', None, None, None, False, False, None, False, None, True, True)
# (44942, 'DZJ36PAW', 'Kennan', 'Dodson', 'Placentia', 'MA', 'Sed@eleifendnecmalesuada.edu', '(685) 633-8561', None, None, False, True, None, True, False, True, False, True)
# (44944, 'NTM02MDQ', 'Driscoll', 'Maddox', 'Webster Groves', 'SK', 'Nam.nulla.magna@quamPellentesque.edu', '(619) 985-8135', False, True, None, None, False, True, None, False, False, None)
# (44945, 'VHT71GNH', 'Madonna', 'Bradshaw', 'Durham', 'DC', 'nibh.Aliquam@duilectusrutrum.org', '(683) 211-9571', True, False, False, False, None, None, False, False, True, False)
# (44948, 'WXQ04UXE', 'Russell', 'Hamilton', 'Saipan', 'YT', 'in.lobortis.tellus@lobortisrisusIn.ca', '(302) 946-2005', None, None, None, False, True, True, True, False, None, False)
# (44950, 'BJR21FIF', 'Benjamin', 'Chang', 'Sister Bay', 'NB', 'mauris@vitaealiquet.edu', '(129) 220-1976', None, False, True, None, True, None, True, True, None, True)
# (44952, 'XFD03FZJ', 'Sawyer', 'Dalton', 'Detroit', 'AB', 'orci.Ut.semper@semconsequat.edu', '(109) 995-8192', None, None, None, False, True, None, False, None, True, False)
# (44955, 'WQA09RUA', 'Kyla', 'Osborne', 'Des Moines', 'MD', 'penatibus@hymenaeosMaurisut.org', '(890) 857-6227', True, None, False, None, None, None, True, None, None, True)
# (44956, 'RNT51NFJ', 'Rachel', 'Villarreal', 'Charleston', 'MT', 'eu.odio.Phasellus@FuscemollisDuis.org', '(407) 902-1340', None, None, None, None, False, None, True, False, None, True)
# (44958, 'CJI26AAJ', 'Ora', 'Guerra', 'Sharon', 'BC', 'netus.et.malesuada@orci.edu', '(504) 885-7968', None, True, None, False, False, True, None, False, None, False)
# (44960, 'TZD66HFP', 'Kerry', 'Poole', 'Duquesne', 'NM', 'Curae;@lectusa.ca', '(958) 467-6362', None, None, True, None, None, True, False, None, True, None)
# (44961, 'RXQ05JTY', 'Alea', 'Aguilar', 'Wisconsin Rapids', 'SK', 'ornare.placerat.orci@nostraperinceptos.org', '(910) 592-6922', None, None, None, None, False, True, True, True, None, None)
# (44962, 'MIC93KOH', 'Mara', 'Spears', 'Northampton', 'TN', 'erat.volutpat@ligulaNullamfeugiat.org', '(644) 442-1376', False, True, None, None, True, False, False, None, None, None)
# (44965, 'HFW22EXV', 'Damon', 'King', 'Hannibal', 'QC', 'mattis@blanditcongueIn.org', '(671) 181-3373', None, None, True, None, None, None, None, False, True, False)
# (44967, 'MTR25MUN', 'Rinah', 'Brennan', 'Hattiesburg', 'OR', 'pellentesque.tellus@lobortisquispede.org', '(686) 313-0884', True, False, None, True, True, None, None, False, True, None)
# (44973, 'CTC48GZC', 'Murphy', 'Clay', 'Claremont', 'YT', 'ipsum@lacusMaurisnon.com', '(895) 875-9326', True, None, None, False, None, None, True, True, False, True)
# (44974, 'BXN86BWZ', 'Genevieve', 'Lott', 'Needham', 'IA', 'elementum.dui@Sed.org', '(519) 174-5417', None, None, True, True, False, None, False, True, True, None)
# (44975, 'GFL29XVL', 'Alan', 'Meyers', 'Sonoma', 'BC', 'rhoncus.Proin.nisl@ac.ca', '(130) 624-2849', False, None, None, None, False, False, None, False, True, None)
# (44976, 'UWN41ZQZ', 'Hollee', 'May', 'Springfield', 'PA', 'turpis.Aliquam.adipiscing@nec.com', '(523) 967-4730', None, None, None, None, None, False, None, None, None, True)
# (44977, 'RBH57AZN', 'Hayley', 'Blair', 'Santa Fe Springs', 'WV', 'velit.Cras@Maecenas.edu', '(566) 679-6547', None, None, False, True, False, None, None, None, None, False)
# (44978, 'DNC63BIX', 'Josephine', 'Bond', 'Enid', 'MO', 'purus.Duis@posuereatvelit.com', '(634) 163-5552', None, False, None, None, None, None, True, None, None, None)
# (44979, 'PQF63PGX', 'Clare', 'Houston', 'Galesburg', 'MB', 'eu@massaMauris.edu', '(706) 255-3693', True, True, True, True, True, None, False, None, True, False)
# (44981, 'LTT70FNR', 'Linus', 'Cooper', 'Walnut', 'NV', 'tortor.dictum@ornaretortor.edu', '(770) 953-7489', False, False, None, None, None, False, False, None, None, None)
# (44983, 'JNO84KQU', 'Joshua', 'Watkins', 'Fajardo', 'MO', 'hymenaeos@feugiattelluslorem.edu', '(738) 560-5086', None, None, True, None, None, None, True, None, None, None)
# (44985, 'DJO44XEG', 'Karen', 'Vaughan', 'Long Beach', 'NE', 'purus.in@euturpisNulla.com', '(946) 855-7470', None, True, False, None, None, True, None, None, False, None)
# (44987, 'AOV08SMU', 'Hollee', 'Harrington', 'Sedalia', 'MB', 'aliquam.eros.turpis@ametnullaDonec.org', '(959) 854-1190', False, None, None, True, False, None, None, None, False, False)
# (44988, 'YJH79UWD', 'Regan', 'William', 'Utica', 'AB', 'rhoncus@ascelerisque.ca', '(338) 175-1941', False, None, False, True, None, False, True, None, None, None)
# (44989, 'BIW10LIA', 'Sybil', 'Knox', 'Richmond', 'NC', 'libero.Proin.sed@duinectempus.com', '(240) 329-6203', None, True, True, None, False, None, False, None, False, None)
# (44991, 'ESN27FNM', 'Ignatius', 'Barry', 'North Pole', 'VA', 'tristique.ac@eutellusPhasellus.edu', '(652) 133-6882', None, None, True, None, None, None, None, False, None, False)
# (44992, 'QKQ91ICH', 'Tatiana', 'Medina', 'Dixon', 'BC', 'Nullam.lobortis.quam@disparturientmontes.ca', '(477) 437-0825', False, None, None, False, True, False, None, None, False, False)
# (44993, 'KKB87WWP', 'Barrett', 'Holden', 'Manassas Park', 'NC', 'libero.et.tristique@Etiamlaoreet.edu', '(268) 370-5655', None, True, False, True, None, None, None, None, None, False)
# (44994, 'AHI29JTR', 'Xaviera', 'Gallagher', 'Wilson', 'IL', 'aliquam.adipiscing.lacus@magnis.org', '(256) 753-1379', None, None, None, True, True, None, True, True, True, None)
# (44999, 'XMO52VKM', 'Craig', 'Phillips', 'Barrow', 'NU', 'Donec@nectempus.com', '(717) 216-6660', None, False, False, True, False, True, True, True, None, None)
# (45000, 'EQL37CAK', 'Nevada', 'Bryan', 'San Rafael', 'CO', 'id@semperNamtempor.org', '(421) 199-9624', None, False, True, None, False, None, None, None, False, False)
# (45001, 'OXN58KOL', 'Magee', 'Washington', 'Milwaukee', 'NS', 'massa.Mauris.vestibulum@purusgravidasagittis.com', '(823) 555-9121', True, False, None, True, None, True, False, False, True, False)
# (45006, 'AWW23BED', 'Sydnee', 'Ayers', 'Placentia', 'AL', 'vitae.odio@eueros.ca', '(488) 401-6009', True, None, None, False, True, None, None, None, True, False)
# (45008, 'PEI46YPZ', 'Brent', 'Meyer', 'East Lansing', 'ON', 'mi.eleifend@Donec.edu', '(925) 113-8751', True, None, None, True, False, None, False, None, None, False)
# (45009, 'OBV61DNY', 'Omar', 'Patrick', 'Thiensville', 'NT', 'tincidunt.congue@auctorullamcorpernisl.org', '(630) 603-9255', None, None, False, False, None, False, False, None, None, True)
# (45010, 'NXT19ECE', 'Owen', 'Morales', 'Covina', 'NU', 'enim@imperdietnon.ca', '(847) 932-0649', None, None, False, None, None, None, None, True, False, False)
# (45011, 'DBD04ICC', 'Peter', 'Benton', 'Fort Lauderdale', 'SK', 'nec.cursus.a@Vestibulumaccumsan.ca', '(771) 212-9672', None, None, None, False, False, False, None, False, None, None)
# (45012, 'TTE98KWO', 'Christian', 'Burnett', 'Saukville', 'NL', 'vulputate.risus@tacitisociosquad.com', '(769) 890-4024', None, True, None, False, None, None, None, None, False, None)
# (45014, 'PSW20MDO', 'Maryam', 'Acosta', 'Indio', 'PE', 'blandit.congue@elit.ca', '(794) 406-8067', None, False, True, True, None, True, None, True, None, True)
# (45015, 'RWK09AYA', 'Martena', 'Perez', 'Uniontown', 'CA', 'vitae.velit@ipsum.org', '(563) 287-1581', None, None, False, None, None, False, None, False, None, True)
# (45016, 'MJG71ZWT', 'Ronan', 'Alvarado', 'Columbus', 'TN', 'Morbi.quis.urna@nullaatsem.org', '(100) 216-9508', None, False, None, None, True, True, True, None, None, False)
# (45017, 'AUC28UDL', 'Salvador', 'Avila', 'Pawtucket', 'QC', 'Curabitur.ut.odio@aliquet.com', '(613) 470-5355', None, True, True, None, None, True, None, None, False, None)
# (45018, 'UKN11PSN', 'Charles', 'Flores', 'Mayagez', 'QC', 'rhoncus.Donec@tinciduntnuncac.org', '(126) 920-0381', None, True, None, None, False, None, None, True, True, None)
# (45020, 'XGK92LQX', 'Claudia', 'Stafford', 'Atlantic City', 'RI', 'ornare.lectus@ipsumdolorsit.com', '(823) 849-8169', None, False, False, False, False, None, None, False, None, None)
# (45021, 'JID27DCZ', 'Ocean', 'Barrett', 'Kalispell', 'PE', 'est@enim.edu', '(204) 245-9595', True, True, None, None, True, None, None, None, True, False)
# (45027, 'FAY48JCH', 'Ursa', 'Hurst', 'Homer', 'NB', 'vel@ipsum.edu', '(340) 979-8814', None, None, None, None, None, True, False, True, None, None)
# (45030, 'ESN25NXM', 'Berk', 'Kramer', 'West Valley City', 'SD', 'tellus.eu@Integereulacus.ca', '(837) 954-6482', None, None, True, True, None, None, None, False, None, False)
# (45032, 'CUX67EEU', 'Shoshana', 'Mcconnell', 'Muskegon', 'ND', 'volutpat.Nulla.dignissim@nonummy.com', '(388) 144-8966', None, None, None, None, False, None, True, True, None, True)
# (45034, 'SRJ25DQF', 'Chadwick', 'Cooper', 'San Juan Capistrano', 'QC', 'dignissim.magna.a@elitelitfermentum.com', '(622) 127-9044', False, None, None, None, None, None, None, None, None, None)
# (45035, 'PGW55POO', 'Amber', 'Alston', 'Egg Harbor', 'FL', 'tellus@velest.org', '(698) 622-6436', None, True, False, None, False, None, None, False, None, True)
# (45036, 'WXO41VDQ', 'Clare', 'Rich', 'Butte', 'WI', 'Etiam@aliquet.edu', '(995) 930-6828', True, False, None, None, None, None, False, None, True, None)
# (45037, 'KEN35QBK', 'Scarlet', 'Vance', 'Clairton', 'NC', 'quam@blanditmattisCras.edu', '(202) 773-1417', False, True, False, None, False, None, False, False, False, False)
# (45038, 'QVK35TPB', 'Ursula', 'Fowler', 'Quincy', 'MI', 'sed.hendrerit.a@Curabitur.org', '(830) 831-6511', None, None, None, None, False, None, True, None, None, False)
# (45040, 'XRD15EKU', 'Michael', 'Schroeder', 'Nampa', 'MB', 'ligula.consectetuer.rhoncus@mus.ca', '(181) 177-1103', None, None, None, True, True, False, True, None, None, None)
# (45041, 'XDE99YCD', 'Wilma', 'Huffman', 'North Charleston', 'OH', 'dolor.Quisque@tinciduntadipiscing.ca', '(183) 361-6324', False, False, None, None, False, False, True, None, True, False)
# (45045, 'RME46RPY', 'Dana', 'Bruce', 'Franklin', 'MN', 'urna.Nunc.quis@Donec.org', '(935) 782-0944', None, True, True, False, None, None, None, False, None, True)
# (45048, 'MRG30NOF', 'Derek', 'Morton', 'Murray', 'NL', 'ligula.eu.enim@Donecnonjusto.ca', '(274) 727-1510', True, False, True, False, True, None, None, False, None, False)
# (45053, 'FSX49IMH', 'Nadine', 'Garcia', 'Yigo', 'NT', 'adipiscing@id.com', '(189) 752-2796', None, None, None, None, None, None, None, None, None, True)
# (45054, 'POM31TQV', 'Nevada', 'Dudley', 'Bradford', 'QC', 'volutpat.Nulla.dignissim@molestie.edu', '(212) 463-6141', None, None, None, None, None, False, False, True, None, True)
# (45055, 'VYV26EVT', 'Marvin', 'Ward', 'New Albany', 'ON', 'metus@justofaucibus.com', '(933) 514-0786', None, None, False, None, False, None, False, None, False, None)
# (45056, 'ARS48DON', 'Aimee', 'Cruz', 'Woodward', 'NS', 'Sed.malesuada.augue@vulputateeu.ca', '(224) 605-9940', None, False, True, False, None, None, None, True, None, None)
# (45057, 'HHT83IWG', 'Portia', 'Torres', 'Merced', 'WI', 'molestie@faucibus.org', '(629) 839-4245', None, True, True, True, None, True, None, None, None, True)
# (45063, 'VNX45FOP', 'Martin', 'Holder', 'Biloxi', 'PE', 'mus.Proin.vel@pellentesquetellus.com', '(221) 710-7198', None, True, None, True, False, None, None, None, None, True)
# (45064, 'PGW23YBM', 'Theodore', 'Velez', 'Mount Pleasant', 'ON', 'metus@ipsumleo.com', '(365) 295-1085', None, None, None, None, None, None, False, False, False, None)
# (45065, 'PZV79KWZ', 'Delilah', 'Hooper', 'Aspen', 'QC', 'non@dictumauguemalesuada.org', '(171) 861-7890', None, None, None, None, None, False, False, None, None, None)
# (45066, 'ODF38KBT', 'Heidi', 'Chambers', 'Wichita', 'ON', 'sit.amet.ornare@utpellentesque.org', '(503) 656-1315', False, False, None, True, None, False, True, True, True, False)
# (45068, 'WCS84VLL', 'Rose', 'Woodward', 'Greenfield', 'MB', 'risus.odio@enimnon.edu', '(731) 450-6039', True, False, False, None, True, None, None, None, None, False)
# (45069, 'JZJ74LJM', 'Quamar', 'Foreman', 'Chandler', 'CO', 'Nullam.vitae@ipsum.ca', '(739) 740-8904', None, None, True, None, None, None, None, False, None, False)
# (45070, 'HHZ96ZUP', 'Aileen', 'England', 'Cairo', 'CO', 'urna.Nunc.quis@nisisem.org', '(170) 673-1257', None, None, False, True, True, None, False, True, False, True)
# (45072, 'UMA69OZE', 'Wendy', 'Holman', 'The Dalles', 'WY', 'ipsum.Donec@loremDonecelementum.org', '(374) 179-8416', None, True, None, None, False, True, None, True, True, None)
# (45073, 'VDW89VRI', 'Wallace', 'Harmon', 'Manchester', 'ON', 'ac.urna@duiCumsociis.edu', '(787) 592-0416', None, False, None, None, None, None, False, False, None, True)
# (45074, 'OTG07NCG', 'Nola', 'Pugh', 'Bellingham', 'NL', 'Sed.nulla.ante@Naminterdumenim.org', '(139) 812-7465', None, None, None, False, None, None, False, None, False, False)
# (45075, 'FDH03PUU', 'Constance', 'Hammond', 'Chelsea', 'NL', 'montes.nascetur.ridiculus@quis.ca', '(329) 511-6898', False, True, None, None, False, None, True, None, None, False)
# (45076, 'WFI33MZF', 'Hiram', 'Russo', 'Tupelo', 'TN', 'et@atauctorullamcorper.org', '(869) 137-4719', True, True, None, None, None, False, None, None, False, False)
# (45077, 'XNK98DIP', 'Felicia', 'Gates', 'Fredericksburg', 'SK', 'sed.pede.Cum@Maecenaslibero.com', '(994) 342-4084', False, None, None, True, False, False, None, None, None, True)
# (45079, 'RNV79YEG', 'Jeanette', 'Lang', 'Marshfield', 'OK', 'sed.orci@semPellentesque.ca', '(348) 589-3662', True, None, False, None, True, None, False, False, None, None)
# ...
# (49800, 'QMR22PUQ', 'Galvin', 'Yates', 'College Park', 'MT', 'eu.elit@euerat.ca', '(881) 717-5066', None, False, None, False, False, None, True, False, True, None)
# (49801, 'SGA44TZN', 'Griffith', 'Mcknight', 'Parker', 'SK', 'Nunc@ultrices.org', '(797) 595-0259', True, False, None, None, True, True, None, False, False, None)
# (49805, 'AXE66PGQ', 'Sylvester', 'Buckley', 'Plantation', 'OH', 'sodales.purus@ametconsectetueradipiscing.edu', '(987) 493-1986', True, None, None, None, True, True, False, None, True, None)
# (49810, 'KLP43KTK', 'Carolyn', 'Mcknight', 'Morgan City', 'ON', 'feugiat.Sed.nec@diam.ca', '(607) 467-8401', True, None, True, True, True, None, True, False, True, None)
# (49811, 'GJK60ENM', 'Charles', 'Morris', 'Davis', 'YT', 'lorem@sedorcilobortis.ca', '(891) 450-8875', None, True, None, None, None, False, None, False, True, None)
# (49813, 'DHW96ROL', 'Germane', 'Skinner', 'Pasco', 'PE', 'Donec@auctor.edu', '(729) 438-7424', None, True, False, False, True, True, True, True, None, None)
# (49815, 'DOD61LEN', 'Whitney', 'Rowe', 'Ardmore', 'IL', 'ullamcorper.eu@hendreritconsectetuer.org', '(377) 829-0071', False, None, False, False, True, False, None, False, None, True)
# (49819, 'TAP90QIU', 'Kaden', 'Murphy', 'Fitchburg', 'ON', 'erat.eget.tincidunt@loremDonecelementum.com', '(571) 379-7056', None, None, None, True, False, None, True, None, None, None)
# (49822, 'CRO13CWJ', 'Illiana', 'Dunn', 'Roanoke', 'MN', 'mi@urnaconvalliserat.ca', '(725) 193-5880', None, None, None, None, None, True, True, None, False, True)
# (49823, 'AWD08LPT', 'Eden', 'Nichols', 'Garland', 'TX', 'amet.diam.eu@morbi.com', '(339) 129-4377', True, True, True, False, None, None, None, None, None, True)
# (49825, 'ZLY28VYA', 'Signe', 'Delacruz', 'Rocky Mount', 'NS', 'risus.varius.orci@euaugue.ca', '(953) 126-4158', None, False, None, None, None, None, True, False, None, False)
# (49830, 'KFB33MUW', 'Quemby', 'Juarez', 'Chicago Heights', 'ON', 'non.feugiat.nec@tellusPhaselluselit.ca', '(326) 342-2848', None, None, True, None, None, True, None, None, None, False)
# (49831, 'BCU25AML', 'Hyacinth', 'Graves', 'Joliet', 'NY', 'augue.Sed@cursus.org', '(645) 285-2089', False, None, None, True, None, None, None, None, None, None)
# (49833, 'GDN07BAA', 'Mona', 'Gilbert', 'Monongahela', 'NM', 'risus.Nulla.eget@rutrumlorem.ca', '(969) 154-6065', True, True, True, None, True, None, True, True, True, True)
# (49835, 'VVF64PMP', 'Seth', 'Rivers', 'Moraga', 'QC', 'risus.Nunc@neceuismodin.com', '(437) 896-8790', True, None, True, None, None, False, False, None, None, None)
# (49837, 'ZPR94FZR', 'Alexandra', 'Underwood', 'Clarksville', 'NU', 'velit.Cras@arcu.com', '(484) 652-3544', None, True, None, False, None, None, None, False, True, True)
# (49839, 'HBC60FMA', 'Sydney', 'Byrd', 'St. George', 'NT', 'scelerisque@ultricesVivamusrhoncus.edu', '(214) 457-4625', None, None, None, True, None, None, None, False, None, None)
# (49840, 'RGB07UNK', 'Aretha', 'Blankenship', 'Orem', 'WA', 'velit@massa.com', '(774) 984-4398', None, True, False, None, False, None, None, False, True, None)
# (49842, 'UKX92KPK', 'Iris', 'Butler', 'Santa Barbara', 'NT', 'dis.parturient.montes@Integervulputate.edu', '(172) 206-5217', False, None, None, False, False, None, False, True, None, None)
# (49843, 'JFH42YAL', 'Barry', 'Petersen', 'Deadwood', 'QC', 'eget.tincidunt@Vivamusmolestiedapibus.org', '(687) 361-1114', None, False, None, None, True, None, None, None, True, None)
# (49847, 'VGK39SEF', 'Sasha', 'Briggs', 'Seal Beach', 'KY', 'eu.enim@molestieorcitincidunt.com', '(611) 946-0191', False, None, None, True, None, False, True, False, False, True)
# (49848, 'ZTB92RZJ', 'Linus', 'Case', 'Clemson', 'NL', 'eu.nibh@Nulla.edu', '(516) 686-1124', False, False, None, False, None, False, True, False, None, False)
# (49849, 'IWA87RBZ', 'Tyrone', 'Lowe', 'Rancho Santa Margarita', 'AB', 'Donec@metussitamet.ca', '(164) 442-8846', False, None, False, True, None, None, None, None, None, True)
# (49850, 'GML59QLT', 'Callum', 'Burnett', 'Glen Cove', 'CT', 'pede.ac.urna@felis.ca', '(384) 239-3005', True, None, None, None, None, False, None, None, None, None)
# (49852, 'OQP28EFD', 'Rebekah', 'Hill', 'Rancho Cucamonga', 'NS', 'eget.tincidunt.dui@augueutlacus.edu', '(564) 641-7069', True, None, False, None, None, None, True, False, None, False)
# (49855, 'HVY44DFY', 'Yetta', 'House', 'Chicopee', 'PE', 'Curae;@nec.org', '(467) 619-4314', None, False, None, None, None, False, None, False, None, None)
# (49859, 'ZAC53LWX', 'Davis', 'Hammond', 'Sanford', 'NU', 'Curabitur.dictum.Phasellus@facilisisloremtristique.edu', '(876) 991-4262', None, True, False, None, None, None, False, None, None, None)
# (49860, 'SDY51BAJ', 'Nasim', 'Fleming', 'Des Moines', 'BC', 'Nullam.lobortis.quam@pedeblandit.edu', '(590) 581-5453', False, True, False, True, None, True, True, False, False, None)
# (49865, 'RIU06CJQ', 'Rhonda', 'Walls', 'Bayamon', 'NY', 'Sed@adipiscinglacus.com', '(303) 319-7501', None, None, True, None, None, None, True, None, None, False)
# (49866, 'CZT31TEQ', 'Phelan', 'Fitzgerald', 'Gainesville', 'SK', 'posuere.vulputate.lacus@libero.edu', '(472) 840-1408', None, None, None, True, None, False, True, False, True, None)
# (49868, 'UAK42CWW', 'Michelle', 'Brown', 'Santa Monica', 'MT', 'euismod@enim.com', '(797) 531-9795', None, None, False, None, None, False, None, False, None, None)
# (49871, 'YXT25TBX', 'Gretchen', 'Hutchinson', 'Wheeling', 'CT', 'Nullam.vitae@incursus.ca', '(625) 434-6298', None, None, None, False, True, True, None, None, None, False)
# (49872, 'CDZ54KGS', 'Gray', 'Bonner', 'Tyler', 'NT', 'nibh@semegestasblandit.edu', '(386) 713-8283', None, None, True, False, None, None, None, None, None, False)
# (49873, 'HLW06GXW', 'Barclay', 'Delaney', 'Ypsilanti', 'NL', 'Aliquam.nisl@nec.ca', '(532) 884-2652', None, True, False, True, None, False, None, None, None, None)
# (49874, 'XPH74TZA', 'Fiona', 'Fields', 'Enid', 'TX', 'enim.nec.tempus@justo.ca', '(457) 681-9824', None, True, None, None, None, None, False, None, True, None)
# (49875, 'CRK65NQK', 'Quinn', 'Best', 'Menomonee Falls', 'AB', 'Suspendisse.sed@ipsumdolor.org', '(769) 242-5992', None, True, False, None, False, False, None, True, True, False)
# (49876, 'QQE70JJZ', 'Elijah', 'Montgomery', 'Aguadilla', 'WI', 'Aliquam.gravida.mauris@sollicitudinadipiscingligula.org', '(653) 884-3802', None, False, True, False, False, True, True, None, False, None)
# (49877, 'VSP66AYM', 'Avram', 'Downs', 'Greenville', 'DC', 'risus.Quisque.libero@sitamet.ca', '(977) 674-8500', True, None, None, False, None, True, None, False, False, True)
# (49878, 'DNL72VNT', 'Urielle', 'Lloyd', 'Johnson City', 'LA', 'iaculis@Curae;Phasellusornare.com', '(339) 277-8950', False, None, False, False, None, True, False, None, None, None)
# (49879, 'QNI72DQE', 'Mira', 'Nguyen', 'Tonawanda', 'YT', 'ridiculus.mus@eueleifend.edu', '(869) 542-0333', True, None, False, None, True, None, True, True, False, True)
# (49880, 'DJP67WRD', 'Dominique', 'Baird', 'Saint Louis', 'WY', 'erat@faucibusut.edu', '(931) 420-0763', None, True, None, True, False, True, None, None, True, True)
# (49881, 'TCV13XFD', 'Kenneth', 'Lamb', 'New Iberia', 'QC', 'urna.et@vitae.ca', '(745) 343-7785', None, False, None, None, None, None, False, None, None, True)
# (49885, 'CPU67MXI', 'Raven', 'Gonzales', 'Mechanicville', 'NT', 'sapien.Nunc@sitamet.edu', '(525) 204-5549', None, None, True, True, None, None, None, None, True, False)
# (49887, 'CRN95TDB', 'Stone', 'Whitehead', 'Biloxi', 'WI', 'enim.condimentum.eget@nullaCraseu.org', '(866) 887-8447', None, False, True, True, True, True, True, False, None, True)
# (49890, 'DBW90CQE', 'Ivory', 'Schmidt', 'Lawton', 'OR', 'nonummy.Fusce@Suspendisse.org', '(630) 939-3202', None, None, None, True, False, False, True, False, True, None)
# (49891, 'LSO40NTI', 'Kendall', 'Barr', 'Newport', 'MN', 'purus.mauris.a@arcuiaculis.ca', '(936) 931-6894', None, False, None, False, None, None, None, True, None, None)
# (49895, 'MHA72DFT', 'Odysseus', 'Maxwell', 'San Juan', 'NT', 'vel.nisl.Quisque@enim.edu', '(671) 828-7215', True, False, False, True, False, True, True, True, None, False)
# (49901, 'CUC69PVF', 'Hermione', 'Mcclain', 'Del Rio', 'MB', 'id@Curabitur.org', '(242) 264-7006', True, True, None, None, True, False, False, None, False, None)
# (49903, 'VHI35XBV', 'Ciara', 'Bridges', 'Grand Forks', 'QC', 'sem@ornareFuscemollis.org', '(753) 741-5620', None, False, None, None, None, None, None, None, False, None)
# (49907, 'KOT03JLA', 'Ursula', 'Navarro', 'Eugene', 'YT', 'magnis.dis.parturient@malesuadavel.org', '(419) 954-0934', True, False, True, False, True, False, False, False, True, False)
# (49908, 'HZJ24UIL', 'Casey', 'Rollins', 'Jeffersontown', 'NC', 'rutrum.justo.Praesent@arcuSedeu.ca', '(808) 951-5895', True, True, None, False, True, None, None, False, None, False)
# (49909, 'RXE65JGI', 'Frances', 'Richard', 'Yakima', 'NH', 'tortor.Nunc@pedeNuncsed.edu', '(373) 311-2561', None, None, None, None, None, None, None, True, False, None)
# (49910, 'UUE09JIM', 'Yoshi', 'Hutchinson', 'St. Marys', 'SK', 'luctus.et.ultrices@afacilisisnon.com', '(119) 269-9674', None, None, None, None, False, None, None, False, None, None)
# (49911, 'ZQM13MDZ', 'Dalton', 'Martin', 'Norfolk', 'SK', 'sit.amet@vulputatevelit.org', '(598) 302-2031', None, None, None, False, None, None, True, None, True, None)
# (49912, 'FIN53SVJ', 'Alice', 'Yang', 'Spokane Valley', 'DE', 'amet@sedorci.ca', '(809) 807-9576', True, None, None, False, True, None, False, True, False, True)
# (49914, 'GXI21ZZB', 'Keelie', 'Vasquez', 'Santa Clarita', 'SK', 'magna.et.ipsum@tortorNunccommodo.edu', '(960) 223-1332', True, None, True, True, False, False, None, False, None, False)
# (49916, 'WXK81UQN', 'Darrel', 'Gallagher', 'San Mateo', 'PA', 'id.mollis@rutrum.org', '(844) 350-8522', None, None, False, True, False, True, True, None, False, False)
# (49917, 'GJW48XIL', 'Calista', 'Mcfadden', 'Spartanburg', 'SK', 'montes.nascetur.ridiculus@inconsectetuer.com', '(501) 308-6460', None, True, True, False, None, True, True, None, None, False)
# (49918, 'FUQ58MEH', 'Burton', 'Espinoza', 'Overland Park', 'MB', 'sodales@risus.org', '(294) 179-1618', None, None, False, True, None, None, None, None, None, None)
# (49919, 'QCF79DXN', 'Davis', 'Richardson', 'Thiensville', 'QC', 'felis@orci.edu', '(452) 359-6711', True, None, None, None, None, None, None, None, None, None)
# (49920, 'VOY11XUX', 'Zane', 'Trevino', 'Spokane Valley', 'NC', 'nec@acarcuNunc.org', '(376) 716-1415', None, None, False, False, None, None, True, True, None, True)
# (49922, 'RHP77JSQ', 'Britanni', 'Hernandez', 'Huntington Beach', 'DE', 'aliquet@NullamenimSed.ca', '(116) 162-6722', None, None, False, False, False, False, None, True, True, None)
# (49926, 'RQM93THU', 'Quamar', 'Cole', 'Oneida', 'KS', 'dolor.dapibus.gravida@Vivamuseuismodurna.ca', '(317) 772-1571', None, False, False, False, True, None, None, False, False, False)
# (49927, 'QYD37KMG', 'Claire', 'Monroe', 'Klamath Falls', 'SK', 'amet@lacusUt.com', '(477) 113-6589', None, None, False, False, None, None, True, None, True, False)
# (49928, 'YSY98GPL', 'Buckminster', 'Mccormick', 'Scottsdale', 'NT', 'quis.turpis.vitae@facilisis.org', '(566) 351-3508', None, None, False, None, True, False, False, None, None, None)
# (49933, 'ZFN90CXF', 'Bruce', 'Rivers', 'Meriden', 'NU', 'pharetra@SuspendisseeleifendCras.ca', '(801) 958-5526', None, None, False, None, False, None, False, None, None, None)
# (49934, 'EHY08UPJ', 'Amaya', 'Delaney', 'Kemmerer', 'UT', 'vitae.sodales@ac.ca', '(582) 664-9543', None, None, True, None, None, None, False, None, False, True)
# (49937, 'FFX40WMV', 'Sebastian', 'Rogers', 'New London', 'CA', 'mauris@elit.org', '(991) 496-7090', False, None, False, False, None, True, False, None, True, None)
# (49940, 'JLW73FRI', 'Serina', 'Key', 'York', 'QC', 'sollicitudin@ultricesmaurisipsum.ca', '(268) 292-3525', None, True, False, None, None, False, True, True, False, True)
# (49944, 'FPR31SOP', 'Travis', 'Burch', 'Modesto', 'PA', 'id.nunc.interdum@ametornare.edu', '(771) 370-7659', None, True, None, False, True, None, True, True, False, True)
# (49946, 'FOD03BWS', 'Martina', 'Bender', 'Staunton', 'MA', 'molestie.Sed@metussitamet.com', '(825) 230-6231', None, None, None, False, None, None, None, False, None, None)
# (49947, 'LLV67WHB', 'Chelsea', 'Herman', 'San Marino', 'ON', 'ut@neceuismodin.com', '(137) 375-0856', False, None, False, False, None, None, None, None, None, True)
# (49949, 'TBX37HEF', 'Xena', 'Robinson', 'Fredericksburg', 'NT', 'malesuada.fames@sodales.org', '(701) 705-7159', None, False, None, False, False, None, False, False, None, True)
# (49950, 'QXW39JCE', 'Wang', 'Bray', 'Asbury Park', 'TN', 'vel.mauris@dolorquam.edu', '(652) 846-4883', True, False, None, False, True, True, None, True, None, True)
# (49951, 'XDV75MDK', 'Ella', 'Holland', 'Barrow', 'LA', 'quam@semper.edu', '(986) 699-3527', None, None, None, None, None, False, None, True, False, False)
# (49955, 'JLP95RTS', 'Bryar', 'Peters', 'New Bedford', 'BC', 'nec.leo.Morbi@aliquet.com', '(996) 234-4362', None, True, False, None, None, None, True, None, False, None)
# (49956, 'ZGM15ZOX', 'Marsden', 'Robinson', 'Grand Rapids', 'PE', 'accumsan.laoreet@nuncinterdum.edu', '(721) 487-5326', None, True, False, False, None, None, False, False, None, None)
# (49960, 'AMD21KHG', 'Dalton', 'Fuentes', 'Hawaiian Gardens', 'MD', 'dis.parturient.montes@non.org', '(962) 834-0823', None, None, True, None, False, None, True, None, None, None)
# (49962, 'RWN42FJD', 'Fletcher', 'Maldonado', 'Bell', 'WY', 'malesuada.Integer@magna.com', '(635) 767-0161', None, None, None, True, None, None, False, None, False, False)
# (49963, 'YCR76KVV', 'Alexandra', 'Anderson', 'Alameda', 'MB', 'imperdiet.ornare.In@dis.edu', '(783) 236-3546', None, None, None, False, True, None, False, True, None, None)
# (49964, 'ZDR14HNA', 'Palmer', 'Combs', 'Galesburg', 'TN', 'sem.Nulla@sitametdiam.com', '(795) 676-5408', True, False, None, None, None, True, None, None, False, None)
# (49965, 'WER49IBK', 'Graiden', 'Sutton', 'Chandler', 'QC', 'orci.Ut.semper@sociosquad.edu', '(739) 484-7819', None, None, None, None, True, None, None, False, False, True)
# (49966, 'XXT27FBP', 'Hayden', 'Wilkinson', 'Portland', 'ON', 'ullamcorper.Duis@pharetra.com', '(945) 884-6008', True, True, None, False, False, None, True, False, True, None)
# (49968, 'SRE20ZJV', 'Madison', 'Haynes', 'Tacoma', 'KY', 'in.dolor.Fusce@aliquamerosturpis.ca', '(762) 793-5843', None, True, None, True, False, None, False, None, None, False)
# (49970, 'EAO59OAM', 'Zachary', 'Goodman', 'Oil City', 'SK', 'ipsum.sodales@egetmollislectus.org', '(799) 717-3235', None, None, None, None, False, False, None, None, None, None)
# (49971, 'AKB75VCT', 'Calista', 'Orr', 'Sutter Creek', 'NT', 'erat@ultricies.edu', '(809) 129-4837', None, False, False, None, False, None, True, False, False, True)
# (49973, 'KVB52LOX', 'Harlan', 'Murphy', 'Hot Springs', 'NM', 'Sed.nulla@nec.ca', '(844) 671-5836', None, True, False, None, None, True, False, None, True, True)
# (49976, 'NCU91ZWT', 'Abra', 'Clark', 'Ansonia', 'AK', 'Sed.id@lacusAliquamrutrum.ca', '(141) 404-9766', False, False, None, None, False, None, False, None, False, False)
# (49981, 'ZKH01ATP', 'Oren', 'Blair', 'Arcadia', 'TN', 'velit.Aliquam.nisl@ac.edu', '(601) 271-5851', False, None, None, None, True, None, True, None, True, True)
# (49982, 'DRV24ZUH', 'Karly', 'Wilkinson', 'Albany', 'NS', 'a.sollicitudin.orci@fermentumvel.com', '(395) 154-4900', False, None, None, False, False, None, None, None, False, None)
# (49985, 'EYT93UEA', 'Mallory', 'Reynolds', 'Ypsilanti', 'NU', 'Proin@Class.edu', '(248) 486-4741', None, None, None, False, False, None, True, True, None, None)
# (49987, 'MMK88YWE', 'Lucian', 'Morgan', 'Pomona', 'IN', 'sodales@blanditviverraDonec.ca', '(922) 687-0367', None, True, None, True, False, False, True, None, None, None)
# (49988, 'ERA75TVW', 'Hayden', 'Lyons', 'Chelsea', 'SC', 'in@Donecat.ca', '(383) 842-2235', None, None, None, False, False, True, True, False, False, False)

# %%
print(row)
# Out:
# None

# %%
redshift.delete_cluster(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER, SkipFinalClusterSnapshot=True)
# Out:
# {'Cluster': {'ClusterIdentifier': 'try-naufal-redshift',
#   'NodeType': 'dc2.large',
#   'ClusterStatus': 'deleting',
#   'ClusterAvailabilityStatus': 'Modifying',
#   'MasterUsername': 'awsuser',
#   'DBName': 'myfirstdb',
#   'Endpoint': {'Address': 'try-naufal-redshift.crzycxx5xuqb.ap-southeast-3.redshift.amazonaws.com',
#    'Port': 5439},
#   'ClusterCreateTime': datetime.datetime(2022, 11, 26, 14, 15, 35, 381000, tzinfo=tzutc()),
#   'AutomatedSnapshotRetentionPeriod': 1,
#   'ManualSnapshotRetentionPeriod': -1,
#   'ClusterSecurityGroups': [],
#   'VpcSecurityGroups': [{'VpcSecurityGroupId': 'sg-01ed892c7b5358b3c',
#     'Status': 'active'}],
#   'ClusterParameterGroups': [{'ParameterGroupName': 'default.redshift-1.0',
#     'ParameterApplyStatus': 'in-sync'}],
#   'ClusterSubnetGroupName': 'default',
#   'VpcId': 'vpc-027a391276a2484a3',
#   'AvailabilityZone': 'ap-southeast-3b',
#   'PreferredMaintenanceWindow': 'sun:19:30-sun:20:00',
#   'PendingModifiedValues': {},
#   'ClusterVersion': '1.0',
#   'AllowVersionUpgrade': True,
#   'NumberOfNodes': 1,
#   'PubliclyAccessible': True,
#   'Encrypted': False,
#   'Tags': [],
#   'EnhancedVpcRouting': False,
#   'IamRoles': [{'IamRoleArn': 'arn:aws:iam::312875311692:role/redshift-s3-access',
#     'ApplyStatus': 'in-sync'}],
#   'MaintenanceTrackName': 'current',
#   'DeferredMaintenanceWindows': [],
#   'NextMaintenanceWindowStartTime': datetime.datetime(2022, 11, 27, 19, 30, tzinfo=tzutc()),
#   'TotalStorageCapacityInMegaBytes': 400000,
#   'AquaConfiguration': {'AquaStatus': 'disabled',
#    'AquaConfigurationStatus': 'auto'}},
#  'ResponseMetadata': {'RequestId': '6f25c767-6013-4088-8e68-a4ec8f211ccd',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '6f25c767-6013-4088-8e68-a4ec8f211ccd',
#    'content-type': 'text/xml',
#    'content-length': '2756',
#    'date': 'Sun, 27 Nov 2022 00:56:55 GMT'},
#   'RetryAttempts': 0}}
